# %%
num1=input("Enter ")
num2=input("Enter ")
try:
    print("Sum ",int(num1)+int(num2))

except Exception as e:
    print(e)
# Out:
# Enter 5
# Enter k
# invalid literal for int() with base 10: 'k'
