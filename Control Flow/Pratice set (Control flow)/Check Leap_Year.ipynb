# %%
# check Leap_Year

# %%
year=int(input("Enter a Year"))
if year%400==0 and year%100==0 or year%4==0:
    print("it is leap Year ",year)
else:
    print("It is not a leap Year ",year)
# Out:
# Enter a Year2001
# It is not a leap Year  2001

# %%
year=int(input("Enter a Year"))
if year%400==0 and year%100==0 or year%4==0:
    print("it is leap Year ",year)
else:
    print("It is not a leap Year ",year)
# Out:
# Enter a Year2000
# it is leap Year  2000
