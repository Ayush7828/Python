# %%
# cehck positive and Negative Number

# %%
number=int(input("Enter a number "))
if number>0:
    print("It is Positive NUmber ")
else:
    print("It is Negative Number ")
# Out:
# Enter a number 12
# It is Positive NUmber

# %%
number=int(input("Enter a number "))
if number>0:
    print("It is Positive NUmber ")
else:
    print("It is Negative Number ")
# Out:
# Enter a number -5
# It is Negative Number
