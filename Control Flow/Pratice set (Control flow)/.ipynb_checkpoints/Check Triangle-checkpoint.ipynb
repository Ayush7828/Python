# %%
a=int(input("Enter a first side "))
b=int(input("Enter a second  side "))
c=int(input("Enter a third side "))

if a==b and b==c and a==c:
    print("It is Equilateral Triangle ")
elif a==b or b==c and c==a:
    print("It is isoscles Triangle")
else:
    print("It is Scalene Triangle")
# Out:
# Enter a first side 12
# Enter a second  side 12
# Enter a third side 12
# It is Equilateral Triangle

# %%
a=int(input("Enter a first side "))
b=int(input("Enter a second  side "))
c=int(input("Enter a third side "))

if a==b and b==c and a==c:
    print("It is Equilateral Triangle ")
elif a==b or b==c and c==a:
    print("It is isoscles Triangle")
else:
    print("It is Scalene Triangle")
# Out:
# Enter a first side 45
# Enter a second  side 54
# Enter a third side 54
# It is Scalene Triangle

# %%
a=int(input("Enter a first side "))
b=int(input("Enter a second  side "))
c=int(input("Enter a third side "))

if a==b and b==c and a==c:
    print("It is Equilateral Triangle ")
elif a==b or b==c and c==a:
    print("It is isoscles Triangle")
else:
    print("It is Scalene Triangle")
# Out:
# Enter a first side 2
# Enter a second  side 2
# Enter a third side 4
# It is isoscles Triangle
