# %%
#check even_odd program

# %%
number=int(input("Enter a number "))
if number%2==0:
    print("it is even number ",number)
else:
    print("It is Odd Number ",number)
# Out:
# Enter a number 12
# it is even number  12

# %%
number=int(input("Enter a number "))
if number%2==0:
    print("it is even number ",number)
else:
    print("It is Odd Number ",number)
# Out:
# Enter a number 37
# It is Odd Number  37
