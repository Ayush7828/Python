# %%
#check divisible by 5 and 11

# %%
number=int(input("Enter a number "))
if  number%5==0 or number%11==0:
    print("It is divisible by 5 and 11 ",number)
else:
    print("It is not divisible by 5 and 11 ",number)
# Out:
# Enter a number 22
# It is divisible by 5 and 11  22
