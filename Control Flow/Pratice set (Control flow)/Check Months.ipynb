# %%
#check months

# %%
month=int(input("Enter a month"))
if month==1:
    print("31 Days JAN")
elif month==2:
    print("28 Days FEB")
elif month==3:
    print("31 Days march")
elif month==4:
    print("30 Days April")
elif month==5:
    print("31 Days May")
    
elif month==6:
    print("30 Days June") 
elif month==7:
    print("31 Days July")
elif month==8:
    print("31 Days August")
    
elif month==9:
    print("30 Days September")    
    
elif month==10:
    print("31 Days October")
elif month==11:
    print("30 Days Novemebr") 
elif month==12:
    print("31 Days Decemeber")
# Out:
# Enter a month12
# 31 Days Decemeber
