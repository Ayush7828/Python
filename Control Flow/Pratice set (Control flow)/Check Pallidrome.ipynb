# %%
#check Pallidrome

# %%
number =int(input("Enter a number "))
if number%100==number/10:
    print("It is pallidorme Number ",number)
else:
    print("It is not a pallidrome Number ",number)
# Out:
# Enter a number 131
# It is not a pallidrome Number  131
