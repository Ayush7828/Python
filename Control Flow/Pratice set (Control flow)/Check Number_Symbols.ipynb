# %%
#check number symbol

# %%
char=str(input("Enter a character , number symbol ")
if char>'a'and char<'z' or char>'A'and char<'Z':
    print("Alphabet ")
elif char>48 and char<57:
    print("Number")
else:
    print("Symbols")
# Out:
# Enter a character , number symbol 48
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 2>()
#       2 if char>'a'and char<'z' or char>'A'and char<'Z':
#       3     print("Alphabet ")
# ----> 4 elif char>48 and char<57:
#       5     print("Number")
#       6 else:
#
# TypeError: '>' not supported between instances of 'str' and 'int'
