# %%
#check largest number

# %%
a=int(input("Enter a first Number "))
b=int(input("Enter a second Number "))
c=int(input("Enter a third Number "))

if a>b and a>c:
    print("First NUmber is Greater ",a)
elif b>a and a>c:
    print("Second Number is Greater ",b)
else:
    print("Third Number is Greater ",c)
# Out:
# Enter a first NUmber 24
# Enter a second NUmber 124
# Enter a third NUmber 20
# Second Number is Greater  124

# %%
a=int(input("Enter a first Number "))
b=int(input("Enter a second Number "))
c=int(input("Enter a third Number "))

if a>b and a>c:
    print("First Number is Greater ",a)
elif b>a and a>c:
    print("Second Number is Greater ",b)
else:
    print("Third Number is Greater ",c)
# Out:
# Enter a first Number 124
# Enter a second Number 24
# Enter a third Number 10
# First NUmber is Greater  124

# %%
a=int(input("Enter a first Number "))
b=int(input("Enter a second Number "))
c=int(input("Enter a third Number "))

if a>b and a>c:
    print("First Number is Greater ",a)
elif b>a and a>c:
    print("Second Number is Greater ",b)
else:
    print("Third Number is Greater ",c)
# Out:
# Enter a first Number 12
# Enter a second Number 42
# Enter a third Number 78
# Third Number is Greater  78
