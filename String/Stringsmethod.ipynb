# %% [markdown]
# # String

# %%
"Hello Duniya"
# Out:
# 'Hello Duniya'

# %%
print("Hello \n Duniya")
# Out:
# Hello
#  Duniya

# %%
print('''What's your name
and tell me about your self ?
''')
# Out:
# What's your name
# and tell me about your self ?

# %%
"Hello World"
# Out:
# 'Hello World'

# %%
print(len(4))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 print(len(4))
#
# TypeError: object of type 'int' has no len()

# %%
len('Hello World')
# Out:
# 11

# %% [markdown]
# # String Indexing

# %%
mystring="What's your name ? "

# %%
print(mystring[3])
# Out:
# t

# %%
print(mystring[-4])
# Out:
# e

# %% [markdown]
# # String Slicing

# %%
mystring="abcdefghijklmnhop"

# %%
mystring
# Out:
# 'abcdefghijklmnhop'

# %%
print(mystring[1:4])
# Out:
# bcd

# %%
print(mystring[2:])
# Out:
# cdefghijklmnhop

# %%
print(mystring[:-4])
# Out:
# abcdefghijklm

# %%
print(mystring[::1])
# Out:
# abcdefghijklmnhop

# %%
mystring
# Out:
# 'abcdefghijklmnhop'

# %%
print(mystring[2:7:2])
# Out:
# ceg

# %%
print(mystring[2::2])
# Out:
# cegikmhp

# %%
mystring[::-1]
# Out:
# 'pohnmlkjihgfedcba'

# %% [markdown]
# # String Properties and Methods

# %% [markdown]
# #    Immutability

# %%
#immutability means --> Can Not change

# %%
name="Sam"

# %%
# #if you change like 
# name[0]="P"
# #show this error

# %%
name="Sam"

# %%
lastname=name[1:]

# %%
lastname
# Out:
# 'am'

# %%
'p'+lastname
# Out:
# 'pam'

# %%
lastname='z'

# %%
lastname*10
# Out:
# 'zzzzzzzzzz'

# %%
#add to string nothing to change 
# for example 
'2'+ '3'
# Out:
# '23'

# %%
# and now simple addition to print 
2+3
# Out:
# 5

# %%
x="Hello World"

# %%
x.upper() #convert into uppercase
# Out:
# 'HELLO WORLD'

# %%
x #but not affect again without use string functions
# Out:
# 'Hello World'

# %%
x="HELLO AYUSH"

# %%
x.lower() #convert into lower case
# Out:
# 'hello ayush'

# %%
x.split() #split means remove this word in whole strings
# Out:
# ['HELLO', 'AYUSH']

# %%
x="Hi this is a String"

# %%
x.split('i')
# Out:
# ['H', ' th', 's ', 's a Str', 'ng']

# %%
print("Hello Duniya")
# Out:
# Hello Duniya
