# %%
def my_fun(*args):
    return sum(args)*0.05

# %%
my_fun(40,60,100,100,34)
# Out:
# 16.7

# %%
def my_fun(*args):
    print(args)
# args return as tuple

# %%
my_fun(40,60,100,100,34)
# Out:
# (40, 60, 100, 100, 34)

# %%
# **kwargs return as dictinories
