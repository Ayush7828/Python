# %% [markdown]
# # Comparsion Operator

# %%
# ==,<,>,<=,>= these are Comparsion Operator

# %%
# a=45
# b=78
# print(a==b)
# print(a<b)
# print(a>b)
# print(a<=b)
# print(a>=b)
# Out:
# False
# True
# False
# True
# False

# %%
first=input("Enter First value ")
second=input("Enter Second Value ")
# Out:
# Enter First value 78
# Enter Second Value 788

# %%
#use Comparsion Operator
print(first<second)
print(first>second)
print(first==second)
print(first>=second)
print(first<=second)
# Out:
# True
# False
# False
# False
# True

# %%
#find remainder 
first_number=int(input("Enter a Number"))
second_number=int(input("Enter a Number"))
third_number=first_number%second_number
print(third_number)
# Out:
# Enter a Number12
# Enter a Number3
# 0

# %%
#Find Average 
first_number=int(input("Enter a number "))
second_number=int(input("Enter a second number "))
third_number=int(input("Enter a third number "))
average=(first_number+second_number+third_number)/3.0
print("Average = ",average)
# Out:
# Enter a number 12
# Enter a second number 12
# Enter a third number 96
# Average =  40.0

# %%
#square
number=12
result=number**2
print(result)
# Out:
# 144

# %%
#swap two numbers
a=int(input("Enter  a first number "))
b=int(input("Enter a Second NUmber "))
temp=a
a=b
b=temp
print(a)
print(b)
# Out:
# Enter  a first number 12
# Enter a Second NUmber 24
# 24
# 12

# %%
#swap two number without use third variable
a=int(input("Enter a First Number"))
b=int(input("Enter a Second NUmber"))
a=a+b
b=a-b
a=a-b
print(a)
print(b)
# Out:
# Enter a First Number12
# Enter a Second NUmber24
# 24
# 12
