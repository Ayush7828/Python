# %%
#Logical Operator 
# and
# or
# not

# %%
# and -- both sides true so true if any side is false so output is false
#example
'h'=='h'and 2==2
# Out:
# True

# %%
'h'=='j'and 2==2
# Out:
# False

# %%
# or -- only one side is true so output is true 
#example
'a'=='a'or 2==4
# Out:
# True

# %%
'a'=='b'or 4==4
# Out:
# True

# %%
#not -- return true statement
not 1==1
# Out:
# False

# %%
400>5000
# Out:
# False

# %%
not 400 >5000
# Out:
# True
