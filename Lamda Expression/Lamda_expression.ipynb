# %% [markdown]
# # Lamda expression

# %%
# def my_square_fun(num):
#     return num**2

# %%
# num=int(input("Enter a number "))
# my_square_fun(num)

# %%
def square(num):
    return num**2

# %%
my_num=[1,2,3,4,5]

# %%
map(square,my_num)

# %%
for item in map(square,my_num):
    print(item)
# Out:
# 1
# 4
# 9
# 16
# 25

# %%
# lambda function -- single line of 
add= lambda x=input(),y=input() : x+y
# Out:
# 24
# 12

# %%
print(add)
# Out:
# <function <lambda> at 0x0000022C5675BCA0>
