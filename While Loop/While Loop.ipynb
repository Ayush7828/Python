# %%
# while loop
# synatx:  --->  while some_condition:
#                   statement
#  increment /decrement

# %%
x=0
while x<5:
    print("Hello")
    x=x+1
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello

# %%
# print table
number=int(input("Enter a  number "))
i=1
while i<=10:
    table=number*i
    print(table)
    i=i+1
# Out:
# Enter a  number 4
# 4
# 8
# 12
# 16
# 20
# 24
# 28
# 32
# 36
# 40

# %%
# # break , continue pass 
# break --- > break is used to current cloestest loop
# continue --< continue is used to  top of the closest loop
# pass --> does nothing to all

# %%
x=[1,2,3,5,8,10]
for item in x:
    # comment
    pass
print(x)
# Out:
# [1, 2, 3, 5, 8, 10]

# %%
# x=[1,2,3,5,8,10]
# for item in x:
#     # comment
#     # without pass use error
# print(x)

# %%
name="Ayush"
for letter in name:
    print(letter)
# Out:
# A
# y
# u
# s
# h

# %%
# use Contine use statement

name="Ayush"
for letter in name:
    if letter=='y':
        continue
    print(letter)
# Out:
# A
# u
# s
# h

# %% [markdown]
# # break Statement

# %%
x=0
while x<10:
    if x==7:
        break
    print(x)
    x=x+1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
# reverse number
number=int(input("Enter a number "))
while number>1:
    print(number)
    number-=1
# Out:
# Enter a number 10
# 10
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2
