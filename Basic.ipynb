# %%
print("Hello")
# Out:
# Hello

# %%
print('tushar')
# Out:
# tushar

# %% [markdown]
# new notebook

# %% [markdown]
# # Baisc Arithmetic Operator

# %%
print(3+5)
# Out:
# 8

# %%
print(85-63)
# Out:
# 22

# %%
print(41-30)
# Out:
# 11

# %%
print(3*8)
# Out:
# 24

# %%
print(50/5)
# Out:
# 10.0

# %%
print(8//2)
# Out:
# 4

# %%
print(96//12)
# Out:
# 8

# %% [markdown]
# # Module Operator

# %%
7%4
# Out:
# 3

# %%
50%5
# Out:
# 0

# %%
50%2
# Out:
# 0

# %%
75%4
# Out:
# 3

# %%
2**4
# Out:
# 16

# %%
2+10*10+3
# Out:
# 105

# %% [markdown]
# # Variable

# %%
a=50

# %%
a
# Out:
# 50

# %%
a=78

# %%
a
# Out:
# 78

# %%
a=a

# %%
a
# Out:
# 78

# %%
a=10

# %%
a
# Out:
# 10

# %%
a=a+a

# %%
a
# Out:
# 20

# %%
b=45

# %%
b
# Out:
# 45

# %%
c=786

# %%
c
# Out:
# 786

# %%
a=b

# %%
b
# Out:
# 45

# %%
print(a==b)
# Out:
# True

# %%
print("Duniya Hello ")
# Out:
# Duniya Hello

# %%
print(45<78)
# Out:
# True

# %%
print(12<10)
# Out:
# False

# %%
type(a)
# Out:
# int

# %%
b=7.56

# %%
type(b)
# Out:
# float

# %%
a="Ayush singh"

# %%
print(type(a))
# Out:
# <class 'str'>

# %%
my_income=1000
my_taxes=0.2
tax_rate=my_income * my_taxes

# %%
print(tax_rate)
# Out:
# 200.0

# %% [markdown]
# # Strings

# %%
'Hello My name is ayush '
# Out:
# 'Hello My name is ayush '

# %%
"Hello's , what your name"
# Out:
# "Hello's , what your name"

# %%
''' राष्ट्रपिता जो कहे जाते है,
प्यार से बापू उन्हें बुलाते हैं।\n
जिन्होंने देश को आज़ाद कराया।\n
सत्य अहिंसा का पाठ पढ़ाया।\n
महात्मा गांधी वो कहलाते हैं।
'''
# Out:
# ' राष्ट्रपिता जो कहे जाते है,\nप्यार से बापू उन्हें बुलाते हैं।\n\nजिन्होंने देश को आज़ाद कराया।\n\nसत्य अहिंसा का पाठ पढ़ाया।\n\nमहात्मा गांधी वो कहलाते हैं।\n'

# %%
print("Hello \n World")
# Out:
# Hello
#  World

# %%
print("Hello \n what's your name \n what's your country name ")
# Out:
# Hello
#  what's your name
#  what's your country name

# %%
print("Ayush \t Singh")
# Out:
# Ayush 	 Singh

# %%
len('Ayush')
# Out:
# 5

# %%
len( "I'm good ")
# Out:
# 9
