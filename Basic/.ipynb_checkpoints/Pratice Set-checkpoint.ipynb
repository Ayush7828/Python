# %%
# addition program

first_number=int(input("Enter a first Number "))
second_number=int(input("Enter a Second Number "))
third_number=first_number+second_number
print(third_number)
# Out:
# Enter a first Number 45
# Enter a Second Number 2
# 47

# %%
#float number addition
first_number=float(input("Enter a first Number "))
second_number=float(input("Enter a Second Number "))
third_number=first_number+second_number
print(third_number)
# Out:
# Enter a first Number 12.4
# Enter a Second Number 85.45
# 97.85000000000001

# %%
#multiply program
first_number=int(input("Enter a first Number "))
second_number=int(input("Enter a Second Number "))
third_number=first_number*second_number
print(third_number)
# Out:
# Enter a first Number 12
# Enter a Second Number 2
# 24

# %%
#swap two numbers
a=int(input("Enter a First Number "))
b=int(input("Enter a second Number "))
temp=a
a=b
b=temp
print("After Swapping ",a)
print(b)
# Out:
# Enter a First Number 12
# Enter a second Number 24
# After Swapping  24
# 12

# %%
#swap two numbers without use third variable 
a=int(input("Enter a First Number "))
b=int(input("Enter a Second Number "))
a=a+b
b=a-b
a=a-b
print(a," " ,b)
# Out:
# Enter a First Number 12
# Enter a Second Number 24
# 24   12
