# %%
# functions

# %%
# A function is a block of code to carry out a specific task, will contain its own scope and is called by name. All functions may contain zero(no) arguments or more than one arguments. On exit, a function can or can not return one or more values.

# %%
# syntax:
#  def function_name():
#         # statement

# %%
def my_function():
    print("Hello Ayush")
    print("Hello Duniya")

# %%
my_function()
# Out:
# Hello Ayush
# Hello Duniya

# %%
def add_number(num1,num2):
    return num1+num2

# %%
add_number(45,23.5)
# Out:
# 68.5

# %%
def add_number(num1,num2):
    return num1+num2

# %%
add_number(45,35)
# Out:
# 80

# %%
def my_function(a,b):
    return sum((a,b))*0.05

# %%
my_function(40,60)
# Out:
# 5.0

# %% [markdown]
# # Default Parameter

# %%
#example
def my_func(name="Ayush"):
    return name

# %%
my_func("Tushar")

# if you dont pass any paramter in call time function so this output is ayush
# but you given parameter print output value
# Out:
# 'Tushar'
