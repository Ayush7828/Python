# %% [markdown]
# # Set

# %%
#define empty set
set_var=set()
print(set_var)
# Out:
# set()

# %%
#create set
set_var={'iron-man','Thor'}
print(set_var)
# Out:
# {'Thor', 'iron-man'}

# %% [markdown]
# # define--->
# A Set is an unordered collection data type that is iterable, mutable and has no duplicate elements.

# %%
set_var={1,2,3,4,4}

# %%
set_var
# Out:
# {1, 2, 3, 4}

# %%
set_var={1,2,"Ayush"}
print(set_var)
type(set_var)
# Out:
# {1, 2, 'Ayush'}
# set

# %%
#built in function
# set is not supported indexed

# %%
# example of indexing

# %%
set_var[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 set_var[0]
#
# TypeError: 'set' object is not subscriptable

# %%
# Inbuilt function in sets

# %%
set_var.add('Tushar')

# %%
set_var
# Out:
# {1, 2, 'Ayush', 'Tushar'}

# %%
# difference -- this function to remove common elements sets

# %%
set1={'ayush','tushar','shubham','hulk'}
set2={'ayush','tushar','shubham','Hitman'}

# %%
print(set1)
print(set2)
# Out:
# {'tushar', 'hulk', 'ayush', 'shubham'}
# {'Hitman', 'tushar', 'ayush', 'shubham'}

# %%
set2.difference(set1)
# Out:
# {'Hitman'}

# %%
#update the set use difference_update() function

# %%
set2.difference_update(set1)

# %%
print(set2)
# Out:
# {'Hitman'}

# %%
# union function

# %%
people={'Rakesh','Virat','Rupesh'}
vampire={'Raju','krishna'}
dracula={'kaju','Anand'}

population=people.union(vampire)

# %%
print(population)
# Out:
# {'Rupesh', 'krishna', 'Rakesh', 'Virat', 'Raju'}

# %%
set1=set()
set2=set()
for i in range(5):
    set1.add(i)
for j in range(3,9):
    set2.add(j)
# intersection 
set3=set2.intersection(set1)

# %%
print(set3)
# Out:
# {3, 4}
